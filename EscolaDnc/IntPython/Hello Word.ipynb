# %%
"""
Este é um comentario de duas linhas
esta é a segunda linha
"""
print("Este é o meu primeiro programa!")
print("Este é o meu segundo print...")
# Out:
# Este é o meu primeiro programa!
# Este é o meu segundo print...
